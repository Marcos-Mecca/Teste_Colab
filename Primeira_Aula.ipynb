# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcos-Mecca/Teste_Colab/blob/main/Primeira_Aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Primeiro uso do Google Colab

import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(200)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 150, where=(ys > 150), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
